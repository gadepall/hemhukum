# %%
import math
x = [10,13/2]
y = [math.sqrt(3)*3,math.sqrt(3)*5/2]
n = ["$P_{1}$","$P_{2}$"]
fig, ax = plt.subplots()
ax.scatter(x, y)
plt.plot(x,y)

for i, txt in enumerate(n):
    ax.annotate(txt, (x[i], y[i]))
plt.plot(x,y)
import numpy as np
import matplotlib.pyplot as plt
i=0        # intercept
s=math.sqrt(3)      
x1=np.linspace(0,10)   
plt.plot(x1, s*x1 + i,label="Y - axis")       
plt.xlabel('X - axis')
# naming the y axis
plt.ylabel('Transformed Y - axis')
leg = plt.legend(loc='upper right')
# giving a title to my graph
plt.title('Distance between points $P_{1}$ & $P_{2}$')
plt.grid()
# function to show the plot
plt.show()

# %%
plt.savefig('books_read.png')
